# %% [markdown]
# ![473163.png](data:image/png;base64,...)

# %%
#@markdown <h2>←Mount Google Drive.
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# %%
 #@markdown <h2>←Upgrade Tidal-dl.
# !pip3 install --upgrade tidal-dl

# %%
#@markdown <h2>←Tidal-dl Configuration.
# !tidal-dl
